# %% [markdown]
# # Visualizations for Final Presentation
#
# In this notebook, we run the scripts that generate the visualizations used in our Final Presentation.

# %% [markdown]
# Below, we generate the table used to display the raw data we received from Kaggle, before any pre-processing is done. For the remaining pre-processing and model training/evaluations, see the notebook located in the SentimentAnalysis folder.

# %%
import pandas as pd

# From https://www.kaggle.com/kazanova/sentiment140
df = pd.read_csv('./SentimentAnalysis/training.1600000.processed.noemoticon.csv', encoding='latin-1', header=None)
df.columns = ['target','ids','date','flag','user','text']
df
# Out:
#          target         ids                          date      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %% [markdown]
# The following commands just navigate us to the right directory where the visualization scripts are located. We then enable the matplotlib figures to be displayed in jupyter. It is important to note that the figures are a less appealing when displayed in the jupyter-notebook. The figure titles and axes are cleaner (matching the ones in the slides) when outputted via a normal command line.

# %%
pwd
# Out:
# 'C:\\Users\\Chris\\Documents\\ECE 143\\ECE-143-Team4'

# %%
cd Functions/
# Out:
# C:\Users\Chris\Documents\ECE 143\ECE-143-Team4\Functions

# %%
# %matplotlib qt
# %matplotlib inline

# %% [markdown]
# Below, we can see the script generating the chronological graph results for usernames we used in the final presentation.

# %%
# %run chronological_tweets.py
# Out:
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ...

# %% [markdown]
# The bars in these figures represent days, the height being the quantity of tweets, the color being the overall sum of positive/negative tweets, and the cyan dotted line a moving average of the quantity of tweets.

# %%
# %run chronological_tweets.py
# Out:
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ...

# %% [markdown]
# (**Note**: these figures and tweets differ from the ones in our presentation due to the different times they were drawn. For purpose of relating to our slides, the commends made here are the same as in our presentation.)
# One of the most negative users we encountered was IRSnews. This can be explained by their continuous efforts to combat identity thieft.
#
# Example Negative Tweet:
# "#IRS doesn't call taxpayers demanding personal info, payments or threats of lawsuits or arrests..."

# %%
# %run chronological_tweets.py
# Out:
# Chronological tweets analysis, by user
# Please input bearer token: AAAAAAAAAAAAAAAAAAAAACU5MQEAAAAAb8IG9iHnFcLZJIMfitvGF7AT2bU%3D1aHtYkLgspMIQ9NqK9uffW7MHmNhTDG0e1hZNJp5Nd4DOiBFV0
# new search? (y/n): y
# Input twitter username: VP
# 200
# {
#     "data": [
#         {
#             "created_at": "2016-11-29T20:16:39.000Z",
#             "description": "Vice President of the United States. Wife to the first @SecondGentleman. Momala. Auntie. Fighting for the people.",
#             "id": "803694179079458816",
#             "name": "Vice President Kamala Harris",
#             "username": "VP"
#         }
#     ]
# }
# Username found: Vice President Kamala Harris. Proceed with search? (y/n): y
# Input quantity of most recent tweets to analyze (100-3,200 in 100 intervals): 1800
# Select the model to use: Tf-Idf (1) or Count Vectorizer (2): 1
# Retrieving up to  1800  of the most recent tweets of user:  Vice President Kamala Harris ...
# Pagination progress:  1 / 18
# ...

# %% [markdown]
# Here, we see a negative spike around the time former President Trump announced COVID-19 a national emergency. The tweets that followed appear to be negatively influenced.

# %%
# %run chronological_tweets.py
# Out:
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ...

# %% [markdown]
# Jack Dorsey, CEO of Twitter Inc.
#
# His most positive tweet:
# "@AmigoTheDevil great show at Pappys! Thank you"
#
# Something we noticed is that individual users are generally positive. Possibly an indication of how social media influences our awareness on a forum that can be seen by anyone.

# %% [markdown]
# ## TODO Sonya wordclouds

# %%
# %run chronological_tweets.py
# Out:
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Chris\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.24.1 when using version 0.23.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# ...
